# %% [markdown]
# <a href="https://colab.research.google.com/github/doan362687264/NhanDang/blob/main/TienGiay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
folder= '/content/drive/MyDrive/tiengiay/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder + 'dollar.'+ str(i) +'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()
folder = '/content/drive/MyDrive/tiengiay/'

photos, labels = list(), list()

for file in listdir(folder):
  if file.startswith('motngandong'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('haingandong'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('namngandong'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('muoingandong'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('haimuoingandong'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('nammuoingandong'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('mottramngandong'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('haitramngandong'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('dollar'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('Malaysia'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
    
 
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200,200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos, labels, batch_size=64,epochs=100, verbose=1)
model.save('11money.h5')
# Out:
# Mounted at /content/drive
# (464, 200, 200, 3) (464,)
# Epoch 1/100
# 8/8 [==============================] - 14s 204ms/step - loss: 1222.9071 - accuracy: 0.1078
# Epoch 2/100
# 8/8 [==============================] - 1s 148ms/step - loss: 10.7289 - accuracy: 0.4181
# Epoch 3/100
# 8/8 [==============================] - 1s 149ms/step - loss: 0.5496 - accuracy: 0.8341
# Epoch 4/100
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1020 - accuracy: 0.9784
# Epoch 5/100
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0453 - accuracy: 0.9892
# Epoch 6/100
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0074 - accuracy: 0.9978
# Epoch 7/100
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 8/100
# 8/8 [==============================] - 1s 148ms/step - loss: 5.4107e-05 - accuracy: 1.0000
# Epoch 9/100
# 8/8 [==============================] - 1s 147ms/step - loss: 3.7134e-06 - accuracy: 1.0000
# ...

# %%
classes = ["motngandong","haingandong","namngandong","muoingandong","haimuoingandong","nammuoingandong","mottramngandong","haitramngandong","dollar","Malaysia"]
img = load_img('/content/drive/MyDrive/tiengiay/dollar.16.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.09228303 0.09871417 0.08943702 0.09087595 0.10650201 0.10158936
#   0.10538206 0.10801347 0.11568187 0.09152109]]
# 'dollar'

# %%
#Check
classes = ["motngandong","haingandong","namngandong","muoingandong","haimuoingandong","nammuoingandong","mottramngandong","haitramngandong","dollar","Malaysia"]
img = load_img('1.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255

y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
