# %% [markdown]
# <a href="https://colab.research.google.com/github/doan362687264/NhanDang/blob/main/TraiCay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
folder= '/content/drive/MyDrive/TraiCay/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder + 'apple'+ str(i) +'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()
folder = '/content/drive/MyDrive/TraiCay/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('apple'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banana'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('corn'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('kiwi'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('leamon'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('mango'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('onion'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('pear'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('plum'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('Potato'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
    
 
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200,200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos, labels, batch_size=64,epochs=100, verbose=1)
model.save('10fruits.h5')
# Out:
# Mounted at /content/drive
# (268, 200, 200, 3) (268,)
# Epoch 1/100
# 5/5 [==============================] - 13s 147ms/step - loss: 1348.0687 - accuracy: 0.0746
# Epoch 2/100
# 5/5 [==============================] - 0s 73ms/step - loss: 300.4710 - accuracy: 0.1679
# Epoch 3/100
# 5/5 [==============================] - 0s 73ms/step - loss: 35.2207 - accuracy: 0.3134
# Epoch 4/100
# 5/5 [==============================] - 0s 73ms/step - loss: 2.7125 - accuracy: 0.6194
# Epoch 5/100
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0961 - accuracy: 0.9776
# Epoch 6/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 9/100
# 5/5 [==============================] - 0s 72ms/step - loss: 1.2178e-04 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 74ms/step - loss: 3.3542e-05 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 75ms/step - loss: 9.7970e-06 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 74ms/step - loss: 3.8627e-06 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 74ms/step - loss: 2.0257e-06 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 73ms/step - loss: 1.2254e-06 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 73ms/step - loss: 8.6249e-07 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 72ms/step - loss: 6.5076e-07 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 72ms/step - loss: 5.1598e-07 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 72ms/step - loss: 4.4303e-07 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 76ms/step - loss: 3.9855e-07 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 74ms/step - loss: 3.6430e-07 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 75ms/step - loss: 3.4295e-07 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 75ms/step - loss: 3.2471e-07 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 74ms/step - loss: 3.1092e-07 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 72ms/step - loss: 3.0069e-07 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 73ms/step - loss: 2.8868e-07 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 74ms/step - loss: 2.7890e-07 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 72ms/step - loss: 2.7000e-07 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 72ms/step - loss: 2.5977e-07 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 73ms/step - loss: 2.4998e-07 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 72ms/step - loss: 2.4242e-07 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 75ms/step - loss: 2.3619e-07 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 73ms/step - loss: 2.2952e-07 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 75ms/step - loss: 2.2507e-07 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 74ms/step - loss: 2.1707e-07 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 74ms/step - loss: 2.1217e-07 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 72ms/step - loss: 2.0684e-07 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 93ms/step - loss: 2.0061e-07 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.9750e-07 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.9305e-07 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 88ms/step - loss: 1.8727e-07 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 72ms/step - loss: 1.8504e-07 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 88ms/step - loss: 1.8015e-07 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 80ms/step - loss: 1.7348e-07 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 75ms/step - loss: 1.7170e-07 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 74ms/step - loss: 1.6858e-07 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 73ms/step - loss: 1.6458e-07 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 73ms/step - loss: 1.6147e-07 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.5746e-07 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.5524e-07 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 73ms/step - loss: 1.5079e-07 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 75ms/step - loss: 1.4812e-07 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 73ms/step - loss: 1.4456e-07 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 74ms/step - loss: 1.4234e-07 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 74ms/step - loss: 1.4012e-07 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.3700e-07 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 75ms/step - loss: 1.3344e-07 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 72ms/step - loss: 1.3166e-07 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 75ms/step - loss: 1.2988e-07 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 74ms/step - loss: 1.2855e-07 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.2633e-07 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.2410e-07 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 73ms/step - loss: 1.2188e-07 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 73ms/step - loss: 1.2010e-07 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 75ms/step - loss: 1.1876e-07 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.1654e-07 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.1432e-07 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 75ms/step - loss: 1.1254e-07 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 74ms/step - loss: 1.1120e-07 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 74ms/step - loss: 1.0853e-07 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 73ms/step - loss: 1.0675e-07 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.0409e-07 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 72ms/step - loss: 1.0186e-07 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 74ms/step - loss: 9.9638e-08 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 74ms/step - loss: 9.7858e-08 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 75ms/step - loss: 9.5189e-08 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 75ms/step - loss: 9.4300e-08 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 76ms/step - loss: 9.3410e-08 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 74ms/step - loss: 9.2965e-08 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 75ms/step - loss: 9.1631e-08 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 74ms/step - loss: 9.0741e-08 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 73ms/step - loss: 9.0297e-08 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 73ms/step - loss: 8.8073e-08 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 75ms/step - loss: 8.7183e-08 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 75ms/step - loss: 8.6293e-08 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 70ms/step - loss: 8.4069e-08 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 73ms/step - loss: 8.3180e-08 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 72ms/step - loss: 8.1400e-08 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 72ms/step - loss: 8.0511e-08 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 74ms/step - loss: 7.9176e-08 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 75ms/step - loss: 7.7842e-08 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 72ms/step - loss: 7.7397e-08 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 73ms/step - loss: 7.4728e-08 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 73ms/step - loss: 7.4283e-08 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 74ms/step - loss: 7.3839e-08 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 75ms/step - loss: 7.2504e-08 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 74ms/step - loss: 7.0725e-08 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 75ms/step - loss: 6.8946e-08 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 76ms/step - loss: 6.7611e-08 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 74ms/step - loss: 6.7611e-08 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 73ms/step - loss: 6.6722e-08 - accuracy: 1.0000

# %%
classes = ["apple","banana","corn","kiwi","leamon","mango","onion","pear","plum","Potato"]
img = load_img('/content/drive/MyDrive/TraiCay/apple17.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.12996593 0.08439631 0.0941601  0.10550047 0.09300195 0.11231605
#   0.11379845 0.09686913 0.08504369 0.08494798]]
# 'apple'

# %%
#Check
classes = ["apple","banana","corn","kiwi","leamon","mango","onion","pear","plum","Potato"]
img = load_img('1.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255

y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
